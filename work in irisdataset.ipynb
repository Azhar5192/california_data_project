# %%
import os
os.getcwd()
# Out:
# 'c:\\data-science-course\\db\\machine learning'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'first_ml_model_.ipynb',
#  'iris.data',
#  'work in irisdataset.ipynb']
